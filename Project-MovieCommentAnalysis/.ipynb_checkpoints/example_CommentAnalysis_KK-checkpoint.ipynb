# %%
# Ignore the warnings
import warnings
# warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# System related and data input controls
import os

# Auto reload of library
# %reload_ext autoreload
# %autoreload 2

# Python path
import sys
base_folder = 'DataScience'
location_base = os.path.join(os.getcwd().split(base_folder)[0], base_folder)
location_module = [os.path.join(location_base, 'Module')] 
for each in location_module:
    if each not in sys.path:
        sys.path.append(each)
        
from import_KK import *
from data_KK import *
from preprocessing_KK import *
from preprocessing_text_KK import * ##
from visualization_KK import * ##

from evaluation_KK import *

# %%
# 로딩
df = get_data_from_path(os.path.join(os.getcwd(), 'Data'), folder_name=True)
# 변수명 변환
df.rename(columns={'영화제목':'Title', '작성자':'User', '작성일':'Date', '평점':'Rating', 
                   '리뷰':'Comment', '공감수':'Sympathy', '비공감수':'Non-sympathy'}, inplace=True)
# 날짜 형식 반영
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
# Getting data from 2 folders...
# 0it [00:00, ?it/s]
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 629.34it/s]
#      Title      User           Date         Rating  \
# 0    그대 어이가리  robi**** 2023-03-11 22:33:00    10
# 1    그대 어이가리  yoon**** 2023-03-11 21:36:00    10
# 2    그대 어이가리  wild**** 2023-03-12 11:08:00    10
# 3    그대 어이가리  geni**** 2023-03-12 09:07:00     7
# 4    그대 어이가리  hwia**** 2023-03-12 00:38:00    10
# ..       ...       ...                 ...     ...
# 295    카시오페아  gimd**** 2022-08-18 20:26:00    10
# 296    카시오페아  dbst**** 2022-08-18 14:10:00    10
# 297    카시오페아  gene**** 2022-08-18 12:04:00    10
# 298    카시오페아  juli**** 2022-08-18 09:40:00    10
# 299    카시오페아  alll**** 2022-08-18 09:07:00     6
#
#                                                                                 Comment                                                                               \
# ...
